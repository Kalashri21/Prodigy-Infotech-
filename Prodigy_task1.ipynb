# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalashri21/Prodigy-Infotech-/blob/main/Prodigy_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib

# %%
# URL of the dataset
url ='https://raw.githubusercontent.com/datasets/population/master/data/population.csv'

# Load the dataset
data = pd.read_csv(url)

# %%
# inspect the first few rows of the dataset
print(data.head())

# Inspect the column names
print(data.columns)
# Out:
#   Country Name Country Code  Year  Value
# 0        Aruba          ABW  1960  54608
# 1        Aruba          ABW  1961  55811
# 2        Aruba          ABW  1962  56682
# 3        Aruba          ABW  1963  57475
# 4        Aruba          ABW  1964  58178

# %%
# Inspect the column names
print(data.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Year', 'Value'], dtype='object')

# %%
# Select relevent Columns
population_data = data[['Year','Value']]
population_data
# Out:
#        Year     Value
# 0      1960     54608
# 1      1961     55811
# 2      1962     56682
# 3      1963     57475
# 4      1964     58178
# ...     ...       ...
# 16395  2017  14751101
# 16396  2018  15052184
# 16397  2019  15354608
# 16398  2020  15669666
# 16399  2021  15993524
#
# [16400 rows x 2 columns]

# %%
# create a bar chart
plt.figure(figsize=(10, 6))
plt.bar(population_data['Year'], population_data['Value'])
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Population Growth')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Create a histogram of the population values
plt.figure(figsize=(10, 6))
plt.hist(population_data['Value'], bins=10)
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title('Population Distribution')
plt.show()
